# %%
from apt_importers import *

import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
ep = read_epos('example-data/voldata.epos')

# %%
## bins = np.linspace(0,100,1000)
i,b = np.histogram(ep.Da,bins)
c = b[:-1] + np.diff(b[:2]) * .5

# %%
fig,ax = plt.subplots(1,1,figsize=[10,5])
ax.plot(c,i)
ax.set_xlim(0,50)
ax.set_yscale('log')

# Cl
ax.axvline(35, c='r')
ax.axvline(37, c='r')

# S
ax.axvline(32, c='g') # assigned as O2?

# K
ax.axvline(39, c='purple')

# %%
read_rrng('example-data/rangefile.rrng')
# Out:
# (         name
#  number
#  1           H
#  2           C
#  3           O
#  4          Ca
#  5          Ga
#  6          Na
#  7           N
#  8          59
#  9       52pt5
#  10      44pt5,          lower   upper      vol          comp  colour
#  number
#  1        1.018   1.048  0.00000           H:1  CCCC00
#  2        5.954   6.053  0.00878           C:1  33CC00
#  3       11.895  12.110  0.00878           C:1  33CC00
#  4       12.947  13.040  0.00878           C:1  33CC00
#  5        6.457   6.544  0.00878           C:1  33CC00
#  6       15.869  16.071  0.02883           O:1  33CCFF
#  7       19.838  20.088  0.04351          Ca:1  FFFFCC
#  8       21.875  22.020  0.04351          Ca:1  FFFFCC
#  9       39.807  40.182  0.04351          Ca:1  FFFFCC
#  10      21.450  21.520  0.04351          Ca:1  FFFFCC
#  11      20.940  21.010  0.04351          Ca:1  FFFFCC
#  12      68.707  69.134  0.01960          Ga:1  FF3300
# ...
